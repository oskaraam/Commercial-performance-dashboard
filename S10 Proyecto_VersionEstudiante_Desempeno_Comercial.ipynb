# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
# <br><br>
# Hola <b>Oskar</b! Mi nombre es <b>Andrés Barbosa</b>. Seré tu revisor. Realizaste un buen trabajo.
# <br><br>
# El proyecto cumple con lo solicitado: el dashboard es funcional, coherente y responde las preguntas del negocio a partir de la fuente <code>Andes_Retail_Group_2024_2025</code>. La estructura en dos vistas (<i>Overview</i> y <i>Detail</i>) está bien resuelta, y lo que planificaste en el Paso 3 se refleja en lo que construiste.
# <br><br>
# <b>1) Conexión y preparación de datos</b>
# <br>
# ✅ La carga se realiza correctamente y los datos quedan listos para el análisis, con la jerarquía de fechas (<i>Año</i>/<i>Trimestre</i>/<i>Mes</i>) habilitando el drill-down temporal. Muy bien que aproveches la columna <i>Nivel_Venta</i> del Paso 2 en la tabla de detalle.
# <br><br>
# <b>2) KPIs y medidas</b>
# <br>
# ✅ Los tres KPIs elegidos son los que planificaste: <i>Ingresos</i>, <i>Ganancia</i> y <i>Unidades Vendidas</i>. Muy buen detalle usarlos como visuales <i>KPI</i> con línea de tendencia por año, que ya muestran la comparación interanual de un vistazo.
# <br><br>
# <b>3) Vista Overview</b>
# <br>
# ✅ Buena portada ejecutiva: combina el slicer de <i>Año</i>, la fila de KPIs, el gráfico de <i>Ingresos por mes</i> (<i>lineChart</i>) con el <i>Año</i> como serie —que resuelve la comparación 2024 vs 2025— y los desgloses de <i>Ingresos</i> por <i>País</i> y por <i>Categoría_Producto</i>. La jerarquía visual (título → KPIs → gráficos) es la que planificaste.
# <br><br>
# <b>4) Vista Detalle</b>
# <br>
# ✅ El diagnóstico está bien resuelto: la tabla de detalle (<i>ID_Cliente</i>, <i>ID_Pedido</i>, <i>Región</i>, <i>Estación</i>, <i>País</i>, <i>Nivel_Venta</i>, <i>Ingresos</i>), el gráfico de <i>Ingresos por Trimestre/Mes con País como serie</i> (que responde tu análisis temporal por país) y los <i>Ingresos por Segmento_Cliente</i>. Sumás los slicers de <i>Año</i>, <i>Región</i> y <i>Categoría</i>, cumpliendo el mínimo de filtros, y el botón de navegación entre páginas es un buen detalle.
# <br><br>
# <b>5) Narrativa SCQA</b>
# <br>
# ✅ Aplicás el modelo Situación → Complicación → Pregunta → Respuesta en ambas vistas, y llegás a un hallazgo concreto: la caída de ingresos se concentra en el primer y último cuatrimestre, asociada a menor inversión del segmento Premium en regiones del sur. El mensaje tipo Slack comunica la idea principal.
# <br><br>
# <b>6) Interactividad y diseño</b>
# <br>
# ✅ Navegación intuitiva entre las dos vistas y filtros que responden como se espera.
# <br><br>
# <b>Sugerencias de mejora:</b>
# <br>
# 1) La narrativa SCQA es correcta pero muy breve y tiene varios errores de tipeo y faltas de tildes ("anos", "Por los ingresos"). Te recomiendo desarrollarla un poco más con cifras concretas (cuánto cae el ingreso, qué región y en qué estación) y revisar la redacción, ya que es la parte que traduce el dashboard en conclusiones ejecutivas.
# <br>
# 2) Trabajaste con el mínimo de tres KPIs; considerá sumar un cuarto como <i>Ticket Promedio</i> o <i>Margen %</i> para enriquecer la lectura de rentabilidad.
# <br>
# 3) En la tabla de detalle, el campo de pedidos está como <code>Sum(ID_Pedido)</code>, que suma el identificador. Conviene mostrarlo como <b>conteo</b> (<code>COUNT</code> o <code>DISTINCTCOUNT</code>) para que refleje la cantidad real de pedidos.
# <br><br>
# <b>Resultado:</b> Proyecto aprobado. Buen trabajo. Cumpliste con lo planificado y el dashboard responde las preguntas del negocio con las dos vistas; con los ajustes sugeridos (sobre todo desarrollar la narrativa) quedaría más completo.
# <br><br>
# </div>

# %% [markdown]
# # 📊 Proyecto: Dashboard de desempeño comercial 2024–2025
# Empresa: **Andes Retail Group**
#
# Este notebook servirá como guía estructurada para el desarrollo del proyecto.
# Sigue cada paso y espera feedback del evaluador.

# %% [markdown]
# ## 🔹 Paso 1: Conexión y Exploración
#
# - Importa el archivo excel en Power BI Desktop o en Tableau.
# - Revisa tipos de datos.
# - Identifica columnas clave.
# - Explora estructura general del dataset.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🔹 Paso 2: Preparación de los datos
#
# - Cambia el formato de `Fecha_pedido` a español (Latinoamérica).
# - Corrige los **tipos de datos** de columnas numéricas.
# - Crea una columna condicional `Nivel_Venta` basada en `Ingresos`. Reglas:
#   - Si `Ingresos` es mayor o igual a 1000 → "Venta Alta"
#   - De lo contrario → "Venta Baja"
# - Activa **Vista Perfil de Columna** para validar calidad.
# - Deja el dataset listo para análisis.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🔹 Paso 3: Diseño y planificación del Dashboard (antes y durante la construcción)
#
# - Define qué pregunta responde cada vista (Overview y Detalle).
# - Especifica qué KPIs incluirás y por qué.
# - Explica qué gráfico usarás para cada pregunta y justifica la elección.
# - Describe la jerarquía visual (qué verá primero el usuario).
#     - Indica cómo distribuirás los elementos en la página.
# - Especifica qué filtros o segmentadores usaras.

# %% [markdown]
# ### Diseño y planificación
# ✏️ Describe aquí brevemente tu planificación antes de construir el dashboard.
# - Haz una planeación inicial, después, conforme vayas creando el dashboard, puedes regresar y modificar estas secciones acorde a lo que vayas encontrando.
#
# #### Vista Overview - ¿Cómo ha evolucionado el ingreso total entre 2024 y 2025?
# Especifica qué KPIs incluirás y por qué: (3-4 KPIs)
# - Ingresos: Utilizare un KPI de ingreso para compararlo con los anos correspondiente y ver si existe una diferencia.
# - Ganancia: Utilizare la nueva columna de ganancias, hecha en base a los ingresos-costos.
# - Unidades vendidas: Utilizare las unidades vendidas para hacer una comparacion con las de ano pasado.
# - ...
#
# Explica qué gráfico usarás para cada pregunta y justifica la elección.
# - Gráfico de tiempo: Usare una grafica que me diga los ingresos con respecto al tiempo y comparar la forma con los anos correspondientes para ver si hay similitud en los mismos meses de cada ano.
# - Gráfico comparación geográfica: Usare una grafica de barras para mostrar la diferencia en las ganancias con respecto a los paises. Para ver que pais invierte mas en los productos de la compania.
# - Gráfico comparación clientes/productos: Usare una grafica de barras para comparar categorias de productos en base a los ingresos. Para denotar que categoria de productos es la que vende mas en todos los paises.
# - ...
#
# Descripción de la jerarquía visual:
# - Título
# - KPIs
# - Graficas de barras
# - Grafica temporal
#
# Filtro(s)
# - Año
#
# #### Vista detalle - ¿Por qué se han caido/subido/mantenido los ingresos?
# Explica qué gráfico usarás para cada pregunta y justifica la elección.
# - Gráfico comparación estacional contra ingresos: Gráfico en el tiempo - `Ingresos` vs `Pais y Trimestre` Esta grafica demuestra las diferencias en trimestre de cada pais a lo largo del ano para dar claridad donde hubo mas ventas.
# - Gráfico comparación categoria/producto contra ingresos : Gráfico de barras - `Ingresos` vs `Segmento del cliente`Esta grafica demuestra el ingreso por medio del segmento del cliente, utilizando los filtros notamos que region invirtio menos que el ano pasado.
# - Tabla mostrando 4-6 columnas:
#   - Conteo `ID_Pedido`
#   - Conteo único `ID_Cliente`
#   - Conteo `Pais`
#   - Conteo `Nivel de Venta`
#   - Conteo `Estacion`
#   - Conteo `Region`
#
# Filtros (mínimo 2)
# - `Fecha_pedido`
# - `Region`
# - `Categoria`

# %% [markdown]
# ## 🔹 Paso 4: Crear visualizaciones efectivas
#
# - Construir Vista 1 (Overview Ejecutivo).
# - Construir Vista 2 (Análisis Detallado).
# - Asegurar claridad y coherencia visual.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🔹 Paso 5: Narrativa con Modelo SCQA + mensaje asincrónico
#
# - Escribe la narrativa que
#   - refleja lo que se observa en la **Vista General (Overview)**.
#   - explica los hallazgos en la **Vista Detalle**.
# - Utiliza el modelo **SCQA (Situación, Complicación, Pregunta, Respuesta)**.
# - Mantén la narrativa clara, ejecutiva y breve.
# - Redacta un mensaje ejecutivo tipo Slack resumiendo el insight principal.

# %% [markdown]
# ### Narrativa del Dashboard (Modelo SCQA)
# Se describe de forma estructurada la historia completa del dashboard usando SCQA, incluyendo contexto, problemas detectados, preguntas de negocio y recomendaciones basadas en datos.

# %% [markdown]
# #### 🖥️ Vista General (Overview)
#
# **S (Situación):**
# Los ingresos varian entre anos.
#
# **C (Complicación):**
# Los ingresos estan por debajo del valor esperado respecto a los del ano pasado
#
# **Q (Pregunta):**
# Por los ingresos son menores en el ano 2025?
#
# **A (Respuesta):**
# Hay una disminucion en los ingresos del primer cuatrimestre y el ultimo.
#
# ---
#
# #### 🔎 Vista Detalle
#
# **S (Situación):**
# Los ingresos varian de ano a ano.
#
# **C (Complicación):**
# En algunas estaciones baja la venta.
#
# **Q (Pregunta):**
# Por que bajara la venta en ciertas estaciones?
#
# **A (Respuesta):**
# Hubo menos inversion en regiones del sur entre anos de parte del segmento premium de clientes.

# %% [markdown]
# ### Mensaje asincrónico para Slack (Modelo SCQA)
#
# Resume los insights más importantes en un mensaje breve.
# - Comunica impacto en negocio y acciones recomendadas, como si lo enviaras a stakeholders por Slack.
# - Escribe un mensaje directo y conciso.

# %% [markdown]
# **📊 Actualización desempeño comercial**
#
# Equipo de Andes Retail Group, Al revisar los datos, se observa que en algunas regiones ha disminuido el ingreso proveniente de clientes Premium y Estándar.
#
# Esta situación provoca un impacto grave en las ganancias globales de la empresa. Por lo tanto, el siguiente paso crítico es checar con precisión qué regiones específicas están afectando esta disminución para tomar acciones correctivas inmediatas.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios._

# %% [markdown]
# ## 🚀 Entrega Final
#
# Comparte el acceso a tu proyecto final para revisión.
#
# Incluye **una** de las siguientes opciones, según la herramienta que hayas utilizado:
# - 🔗 Link público del dashboard publicado (Power BI Service o Tableau Public), o
# - 🔗 Link público de Google Drive/OneDrive con el archivo `.pbix`, o
# - ✅ Confirmación de que el archivo `.pbix` fue subido como indica el screencast.
#
# ### 📎 Enlace del proyecto:

# %% [markdown]
# ✏️ (Pega aquí tu link o escribe "Subi mi proyecto a la plataforma")

# %%
https://1drv.ms/u/c/41bf29a0d2f9663e/IQD-NynKavPMRbkDsTN0Tp3nAVwCnjjcViMa4Nj48neS2L0?e=6b2xxF
